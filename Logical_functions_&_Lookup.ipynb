# %%
# Logical functions & Lookup

# %% [markdown]
# Ans Q1  -
#                =if(B2>=40,”Pass”,”Fail”)
#
#
# Ans Q2  -
#              =IF(AND(A2 > 40000, B2 >= 90%), "Bonus", "No Bonus")
#
# Ans Q3  -
# 		=IF(B2>=90, "A", IF(B2>=75, "B", IF(B2>=50, "C",   "Fail")))
#
# Ans Q 4 –
# 		Dept– Finance
#                  Vlookup Function used.
#
# Ans Q5–
# 		=VLOOKUP(45000, A2:B5, 2, TRUE)
#
# Ans Q6 —
# 		=IF(B2>C2, "Exceeded", "Ok")
#
# Ans Q7–
# 		=INDEX(B2:B10, MATCH("E105", A2:A10, 0))
#
# Ans Q8–
# 		=XLOOKUP("E303", A:A, C:C, "Not Found")
